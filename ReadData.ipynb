# %%
import pandas as pd
from io import StringIO

# %%
Data = '{"employee_name":"James", "email" : "james@gmail.com", "job":[{"title1":"Team Lead", "title2":"Sr Developer"}]}'
df = pd.read_json(StringIO(Data))

# %%
df
# Out:
#   employee_name            email  \
# 0         James  james@gmail.com
#
#                                                  job
# 0  {'title1': 'Team Lead', 'title2': 'Sr Developer'}

# %%
df.to_json()
# Out:
# '{"employee_name":{"0":"James"},"email":{"0":"james@gmail.com"},"job":{"0":{"title1":"Team Lead","title2":"Sr Developer"}}}'

# %%
df.to_json(orient = 'index')
# Out:
# '{"0":{"employee_name":"James","email":"james@gmail.com","job":{"title1":"Team Lead","title2":"Sr Developer"}}}'

# %%
df.to_json(orient = 'records')
# Out:
# '[{"employee_name":"James","email":"james@gmail.com","job":{"title1":"Team Lead","title2":"Sr Developer"}}]'

# %%
dataframe = pd.read_csv('https://.data', header = None) ##to do

# %%
df.to_csv("wine.csv")

# %%
url = "https://www.fdic.gov/bank/individual/failed/banklist.html"
df = pd.read_html(url)

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
url = "https://en.wikipedia.org/wiki/Mobile_country_code"
df = pd.read_html(url,match = "Country", header = 0)[0]

# %%
df
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
df_excel = pd.read_excel('excel.xlsx')

# %%
#pickle file : process of converting a Python object into a byte stream to store it in a db, to program state across sessions or transport data over the network
df_excel.to_pickle('df_excel')

# %%
pd.read_pickle('df_excel')
# Out:
#       Name  Age
# 0    Alice   23
# 1      Bob   34
# 2  Charlie   46
